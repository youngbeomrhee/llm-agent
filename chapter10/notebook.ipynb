# %% [markdown]
# # 요구사항 정의서 생성 AI 에이전트 개발

# %%
# !git clone https://github.com/ychoi-kr/llm-agent.git
# Out:
# Cloning into 'llm-agent'...
# remote: Enumerating objects: 635, done.
# remote: Counting objects: 100% (176/176), done.
# remote: Compressing objects: 100% (46/46), done.
# remote: Total 635 (delta 154), reused 130 (delta 130), pack-reused 459 (from 1)
# Receiving objects: 100% (635/635), 1.91 MiB | 2.36 MiB/s, done.
# Resolving deltas: 100% (344/344), done.

# %%
# %cd llm-agent
# %cd chapter10
# Out:
# /Users/youngbeom-rhee/Repositories/study/llm-agent/chapter10/llm-agent
# /Users/youngbeom-rhee/Repositories/study/llm-agent/chapter10/llm-agent/chapter10

# %%
# !pip install langchain==0.3.0 langchain-core==0.3.0 langchain-openai==0.2.0 langgraph==0.2.22 langchain-text-splitters==0.3.0 python-dotenv==1.0.1 pydantic==2.9.2
# Out:
# Collecting langchain==0.3.0
#   Using cached langchain-0.3.0-py3-none-any.whl.metadata (7.1 kB)
# Collecting langchain-core==0.3.0
#   Using cached langchain_core-0.3.0-py3-none-any.whl.metadata (6.2 kB)
# Collecting langchain-openai==0.2.0
#   Using cached langchain_openai-0.2.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting langgraph==0.2.22
#   Downloading langgraph-0.2.22-py3-none-any.whl.metadata (13 kB)
# Collecting langchain-text-splitters==0.3.0
#   Using cached langchain_text_splitters-0.3.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting python-dotenv==1.0.1
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: pydantic==2.9.2 in /Users/youngbeom-rhee/Repositories/study/llm-agent/.venv/lib/python3.12/site-packages (2.9.2)
# Requirement already satisfied: PyYAML>=5.3 in /Users/youngbeom-rhee/Repositories/study/llm-agent/.venv/lib/python3.12/site-packages (from langchain==0.3.0) (6.0.3)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Users/youngbeom-rhee/Repositories/study/llm-agent/.venv/lib/python3.12/site-packages (from langchain==0.3.0) (2.0.43)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/youngbeom-rhee/Repositories/study/llm-agent/.venv/lib/python3.12/site-packages (from langchain==0.3.0) (3.13.0)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in /Users/youngbeom-rhee/Repositories/study/llm-agent/.venv/lib/python3.12/site-packages (from langchain==0.3.0) (0.1.147)
# Requirement already satisfied: numpy<2.0.0,>=1.26.0 in /Users/youngbeom-rhee/Repositories/study/llm-agent/.venv/lib/python3.12/site-packages (from langchain==0.3.0) (1.26.4)
# Requirement already satisfied: requests<3,>=2 in /Users/youngbeom-rhee/Repositories/study/llm-agent/.venv/lib/python3.12/site-packages (from langchain==0.3.0) (2.32.5)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /Users/youngbeom-rhee/Repositories/study/llm-agent/.venv/lib/python3.12/site-packages (from langchain==0.3.0) (8.3.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/youngbeom-rhee/Repositories/study/llm-agent/.venv/lib/python3.12/site-packages (from langchain-core==0.3.0) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /Users/youngbeom-rhee/Repositories/study/llm-agent/.venv/lib/python3.12/site-packages (from langchain-core==0.3.0) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in /Users/youngbeom-rhee/Repositories/study/llm-agent/.venv/lib/python3.12/site-packages (from langchain-core==0.3.0) (4.15.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/youngbeom-rhee/Repositories/study/llm-agent/.venv/lib/python3.12/site-packages (from pydantic==2.9.2) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /Users/youngbeom-rhee/Repositories/study/llm-agent/.venv/lib/python3.12/site-packages (from pydantic==2.9.2) (2.23.4)
# Requirement already satisfied: openai<2.0.0,>=1.40.0 in /Users/youngbeom-rhee/Repositories/study/llm-agent/.venv/lib/python3.12/site-packages (from langchain-openai==0.2.0) (1.109.1)
# Requirement already satisfied: tiktoken<1,>=0.7 in /Users/youngbeom-rhee/Repositories/study/llm-agent/.venv/lib/python3.12/site-packages (from langchain-openai==0.2.0) (0.12.0)
# Collecting langgraph-checkpoint<2.0.0,>=1.0.2 (from langgraph==0.2.22)
#   Downloading langgraph_checkpoint-1.0.12-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/youngbeom-rhee/Repositories/study/llm-agent/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.0) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/youngbeom-rhee/Repositories/study/llm-agent/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.0) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/youngbeom-rhee/Repositories/study/llm-agent/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.0) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/youngbeom-rhee/Repositories/study/llm-agent/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.0) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/youngbeom-rhee/Repositories/study/llm-agent/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.0) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/youngbeom-rhee/Repositories/study/llm-agent/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.0) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/youngbeom-rhee/Repositories/study/llm-agent/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.0) (1.22.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/youngbeom-rhee/Repositories/study/llm-agent/.venv/lib/python3.12/site-packages (from jsonpatch<2.0,>=1.33->langchain-core==0.3.0) (3.0.0)
# Collecting msgpack<2.0.0,>=1.1.0 (from langgraph-checkpoint<2.0.0,>=1.0.2->langgraph==0.2.22)
#   Downloading msgpack-1.1.2-cp312-cp312-macosx_11_0_arm64.whl.metadata (8.1 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/youngbeom-rhee/Repositories/study/llm-agent/.venv/lib/python3.12/site-packages (from langsmith<0.2.0,>=0.1.17->langchain==0.3.0) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /Users/youngbeom-rhee/Repositories/study/llm-agent/.venv/lib/python3.12/site-packages (from langsmith<0.2.0,>=0.1.17->langchain==0.3.0) (3.11.3)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /Users/youngbeom-rhee/Repositories/study/llm-agent/.venv/lib/python3.12/site-packages (from langsmith<0.2.0,>=0.1.17->langchain==0.3.0) (1.0.0)
# Requirement already satisfied: anyio in /Users/youngbeom-rhee/Repositories/study/llm-agent/.venv/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain==0.3.0) (4.11.0)
# Requirement already satisfied: certifi in /Users/youngbeom-rhee/Repositories/study/llm-agent/.venv/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain==0.3.0) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /Users/youngbeom-rhee/Repositories/study/llm-agent/.venv/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain==0.3.0) (1.0.9)
# Requirement already satisfied: idna in /Users/youngbeom-rhee/Repositories/study/llm-agent/.venv/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain==0.3.0) (3.11)
# Requirement already satisfied: h11>=0.16 in /Users/youngbeom-rhee/Repositories/study/llm-agent/.venv/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain==0.3.0) (0.16.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/youngbeom-rhee/Repositories/study/llm-agent/.venv/lib/python3.12/site-packages (from openai<2.0.0,>=1.40.0->langchain-openai==0.2.0) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/youngbeom-rhee/Repositories/study/llm-agent/.venv/lib/python3.12/site-packages (from openai<2.0.0,>=1.40.0->langchain-openai==0.2.0) (0.11.0)
# Requirement already satisfied: sniffio in /Users/youngbeom-rhee/Repositories/study/llm-agent/.venv/lib/python3.12/site-packages (from openai<2.0.0,>=1.40.0->langchain-openai==0.2.0) (1.3.1)
# Requirement already satisfied: tqdm>4 in /Users/youngbeom-rhee/Repositories/study/llm-agent/.venv/lib/python3.12/site-packages (from openai<2.0.0,>=1.40.0->langchain-openai==0.2.0) (4.67.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/youngbeom-rhee/Repositories/study/llm-agent/.venv/lib/python3.12/site-packages (from requests<3,>=2->langchain==0.3.0) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/youngbeom-rhee/Repositories/study/llm-agent/.venv/lib/python3.12/site-packages (from requests<3,>=2->langchain==0.3.0) (2.3.0)
# Requirement already satisfied: regex>=2022.1.18 in /Users/youngbeom-rhee/Repositories/study/llm-agent/.venv/lib/python3.12/site-packages (from tiktoken<1,>=0.7->langchain-openai==0.2.0) (2025.9.18)
# Using cached langchain-0.3.0-py3-none-any.whl (1.0 MB)
# Using cached langchain_core-0.3.0-py3-none-any.whl (405 kB)
# Using cached langchain_text_splitters-0.3.0-py3-none-any.whl (25 kB)
# Using cached langchain_openai-0.2.0-py3-none-any.whl (51 kB)
# Downloading langgraph-0.2.22-py3-none-any.whl (98 kB)
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading langgraph_checkpoint-1.0.12-py3-none-any.whl (17 kB)
# Downloading msgpack-1.1.2-cp312-cp312-macosx_11_0_arm64.whl (85 kB)
# Installing collected packages: python-dotenv, msgpack, langchain-core, langgraph-checkpoint, langchain-text-splitters, langchain-openai, langgraph, langchain
#   Attempting uninstall: python-dotenv
#     Found existing installation: python-dotenv 1.1.1
#     Uninstalling python-dotenv-1.1.1:
#       Successfully uninstalled python-dotenv-1.1.1
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.2.30
#     Uninstalling langchain-core-0.2.30:
#       Successfully uninstalled langchain-core-0.2.30
#   Attempting uninstall: langchain-text-splitters━━━━━━━━━━━━━━━━━━ 2/8 [langchain-core]
#     Found existing installation: langchain-text-splitters 0.2.2 2/8 [langchain-core]
#     Uninstalling langchain-text-splitters-0.2.2:━━━━━━━━━━━━━━ 2/8 [langchain-core]
#       Successfully uninstalled langchain-text-splitters-0.2.2━ 2/8 [langchain-core]
#   Attempting uninstall: langchain-openai0m━━━━━━━━━━━━━━━━━━━ 4/8 [langchain-text-splitters]
#     Found existing installation: langchain-openai 0.1.21━━━━━━ 4/8 [langchain-text-splitters]
#     Uninstalling langchain-openai-0.1.21:0m━━━━━━━━━━━━━━━━━━━ 4/8 [langchain-text-splitters]
#       Successfully uninstalled langchain-openai-0.1.21━━━━━━━━ 4/8 [langchain-text-splitters]
#   Attempting uninstall: langchain━━━━━╺━━━━━━━━━ 6/8 [langgraph]-splitters]
#     Found existing installation: langchain 0.2.13━━━━━━━━━ 6/8 [langgraph]
#     Uninstalling langchain-0.2.13:╺━━━━━━━━━ 6/8 [langgraph]
#       Successfully uninstalled langchain-0.2.13m━━━━━━━━━ 6/8 [langgraph]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8/8 [langchain]/8 [langchain]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain-experimental 0.3.0 requires langchain-community<0.4.0,>=0.3.0, but you have langchain-community 0.2.12 which is incompatible.
# langchain-chroma 0.1.2 requires langchain-core<0.3,>=0.1.40, but you have langchain-core 0.3.0 which is incompatible.
# langchain-community 0.2.12 requires langchain<0.3.0,>=0.2.13, but you have langchain 0.3.0 which is incompatible.
# langchain-community 0.2.12 requires langchain-core<0.3.0,>=0.2.30, but you have langchain-core 0.3.0 which is incompatible.
# Successfully installed langchain-0.3.0 langchain-core-0.3.0 langchain-openai-0.2.0 langchain-text-splitters-0.3.0 langgraph-0.2.22 langgraph-checkpoint-1.0.12 msgpack-1.1.2 python-dotenv-1.0.1
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
import os
# from google.colab import userdata
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()

# os.environ["OPENAI_API_KEY"] = userdata.get("OPENAI_API_KEY")
os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")
os.environ["LANGCHAIN_TRACING_V2"] = "true"
os.environ["LANGCHAIN_ENDPOINT"] = "https://api.smith.langchain.com"
# os.environ["LANGCHAIN_API_KEY"] = userdata.get("LANGCHAIN_API_KEY")
os.environ["LANGCHAIN_API_KEY"] = os.getenv("LANGCHAIN_API_KEY")
os.environ["LANGCHAIN_PROJECT"] = "agent-book"

# %%
# !python -m documentation_agent.main --task "스마트폰용 건강 관리 앱을 개발하고 싶다"
# Out:
# # 요구사항 문서: 스마트폰용 건강 관리 앱
#
# ## 1. 프로젝트 개요
# 스마트폰용 건강 관리 앱은 사용자가 자신의 건강 상태를 통합적으로 관리하고, 개인화된 피드백을 통해 건강한 생활을 유지할 수 있도록 지원하는 애플리케이션입니다. 이 앱은 다양한 건강 관련 데이터를 통합하여 사용자에게 맞춤형 건강 관리 플랜을 제공하고, 직관적인 인터페이스를 통해 사용성을 극대화하는 것을 목표로 합니다.
#
# ## 2. 주요 기능
# 1. **데이터 통합 관리**: 운동 기록, 식단 관리, 수면 추적 등 다양한 건강 데이터를 한 곳에서 통합적으로 관리할 수 있는 기능.
# 2. **개인화된 피드백 및 추천**: AI를 활용하여 사용자의 건강 데이터를 분석하고, 개인 맞춤형 건강 관리 팁 및 운동 계획을 제공.
# 3. **직관적인 UI/UX**: 사용하기 쉬운 인터페이스로, 큰 아이콘과 글씨를 사용하여 정보 접근성을 높임.
# 4. **사회적 기능 강화**: 친구 및 가족과 목표를 설정하고, 진행 상황을 공유하며 응원할 수 있는 소셜 기능.
# 5. **음성 인식 및 알림 기능**: 음성으로 건강 상태를 기록하고, 약 복용 시간 및 운동 시간을 알려주는 알림 기능.
# 6. **건강 정보 제공**: 최신 건강 정보를 제공하고, 예방접종 일정 및 건강 검진 정보를 관리.
# 7. **운동 및 식단 추적**: 개인의 운동 루틴을 설정하고 추적하며, 식단의 영양 정보를 제공.
# 8. **스트레스 관리 및 명상 기능**: 짧은 시간 동안 할 수 있는 명상이나 호흡 운동을 제공하여 스트레스 관리 지원.
#
# ## 3. 비기능 요구사항
# 1. **보안**: 사용자 데이터의 안전한 저장 및 전송을 위한 강력한 보안 프로토콜 적용.
# 2. **성능**: 빠른 응답 시간과 원활한 사용자 경험을 제공.
# 3. **호환성**: 다양한 스마트폰 운영체제(iOS, Android)에서의 원활한 작동.
# 4. **확장성**: 향후 기능 추가 및 업데이트가 용이한 구조.
#
# ## 4. 제약 조건
# 1. **개발 기간**: 6개월 내에 MVP(최소 기능 제품) 출시.
# 2. **예산**: 제한된 예산 내에서 개발 및 마케팅 진행.
# 3. **기술 스택**: 기존 팀의 기술 역량에 맞춘 기술 스택 사용.
#
# ## 5. 타겟 사용자
# 1. **김민수**: 30세 남성, IT 회사 소프트웨어 엔지니어, 건강 관리에 관심이 많음.
# 2. **이수진**: 45세 여성, 주부, 가족의 건강 관리를 위해 스마트폰 활용.
# 3. **박정우**: 22세 남성, 체육학 전공 대학생, 운동과 건강에 관심이 높음.
# 4. **최영희**: 60세 여성, 은퇴한 교사, 건강 관리 필요성을 느끼고 있음.
# 5. **장현석**: 35세 남성, 마케팅 전문가, 바쁜 일상 속에서 효율적인 건강 관리 방법을 찾고 있음.
#
# ## 6. 우선순위
# 1. **데이터 통합 관리 및 개인화된 피드백**: 사용자에게 가장 큰 가치를 제공할 수 있는 핵심 기능.
# 2. **직관적인 UI/UX**: 다양한 연령대의 사용자가 쉽게 접근할 수 있도록 설계.
# 3. **사회적 기능 및 알림 기능**: 사용자 참여와 지속적인 사용을 유도.
# 4. **건강 정보 제공 및 스트레스 관리 기능**: 부가적인 가치를 제공하는 기능.
#
# ## 7. 리스크와 완화 방안
# 1. **리스크**: 데이터 보안 문제로 인한 사용자 신뢰도 하락.
#    - **완화 방안**: 최신 보안 프로토콜 적용 및 정기적인 보안 점검 실시.
# 2. **리스크**: 복잡한 UI로 인한 사용자 이탈.
#    - **완화 방안**: 사용자 테스트를 통해 UI/UX 개선 및 피드백 반영.
# 3. **리스크**: 예산 초과로 인한 개발 지연.
#    - **완화 방안**: 철저한 예산 관리 및 우선순위에 따른 기능 개발.
